# %%
import dtale
import pandas as pd

# %%
train = pd.read_csv("dados/train_split.csv")

# %%
dtale.show(train)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Jeferson:40001/dtale/iframe/4"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# 2024-08-21 11:00:58,658 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,718 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,721 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,723 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,725 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,727 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,729 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,732 - WARNING  - findfont: Font family 'Heiti TC' not found.
# 2024-08-21 11:00:58,734 - WARNING  - findfont: Font family 'Heiti TC' not found.
# ...
